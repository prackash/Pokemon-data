# %%
import pandas as pd
df = pd .read_csv('pokemon_data.csv')
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
Bulb=df.iloc[0:4]
print(Bulb)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
for index, row in df.iterrows():
    print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df_grass= pd.concat([df.loc[df['Type 1'] == "Grass"] ,df.loc[df['Type 2'] == "Grass"]])
df_grass
# Out:
#        #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison  45      49       49       65
# 1      2                Ivysaur  Grass  Poison  60      62       63       80
# 2      3               Venusaur  Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 48    43                 Oddish  Grass  Poison  45      50       55       75
# ..   ...                    ...    ...     ...  ..     ...      ...      ...
# 783  710    PumpkabooSuper Size  Ghost   Grass  59      66       70       44
# 784  711  GourgeistAverage Size  Ghost   Grass  65      90      122       58
# 785  711    GourgeistSmall Size  Ghost   Grass  55      85      122       58
# 786  711    GourgeistLarge Size  Ghost   Grass  75      95      122       58
# 787  711    GourgeistSuper Size  Ghost   Grass  85     100      122       58
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Generation', 'Attack'], ascending=[0,1])
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 733  665                 Spewpa      Bug       NaN   45      22       60
# 790  714                 Noibat   Flying    Dragon   40      30       35
# 732  664             Scatterbug      Bug       NaN   38      35       40
# 727  659               Bunnelby   Normal       NaN   38      36       38
# 737  669                Flabébé    Fairy       NaN   44      38       39
# ..   ...                    ...      ...       ...  ...     ...      ...
# 19    15  BeedrillMega Beedrill      Bug    Poison   65     150       40
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 137  127      PinsirMega Pinsir      Bug    Flying   65     155      120
# 141  130  GyaradosMega Gyarados    Water      Dark   95     155      109
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#  Total = 'HP' + 'Attack' + 'Defense' + 'Sp. Atk' + 'Sp. Def' + 'Speed'
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
cols = list(df.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
# Reorder the columns
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.to_csv('modified.csv', index=False)

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#      #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison    525   80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 2   45              Vileplume  Grass  Poison    490   75      80       85
# 3   71             Victreebel  Grass  Poison    490   80     105       65
# 4  591              Amoonguss  Grass  Poison    464  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %%
df.loc[df['Total']> 500, ['Generation', 'Legendary']] = ['Test 1', 'Test 2']
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df = pd.read_csv('modified.csv')
df['count'] = 1
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
df_grass= pd.concat([df.loc[df['Type 1'] == "Grass"] ,df.loc[df['Type 2'] == "Grass"]])
df_grass.shape[0]
# Out:
# 95

# %%
types=pd.DataFrame(df['Type 1'].unique())

# %%
types.rename(columns={0:'Type'}, inplace=True)

# %%
types['count']=0
types
# Out:
#         Type  count
# 0      Grass      0
# 1       Fire      0
# 2      Water      0
# 3        Bug      0
# 4     Normal      0
# 5     Poison      0
# 6   Electric      0
# 7     Ground      0
# 8      Fairy      0
# 9   Fighting      0
# 10   Psychic      0
# 11      Rock      0
# 12     Ghost      0
# 13       Ice      0
# 14    Dragon      0
# 15      Dark      0
# 16     Steel      0
# 17    Flying      0

# %%
types.rename(columns={'count':'Count'}, inplace=True)

# %%
types
# Out:
#         Type  Count
# 0      Grass     95
# 1       Fire     64
# 2      Water    126
# 3        Bug     72
# 4     Normal    102
# 5     Poison     62
# 6   Electric     50
# 7     Ground     67
# 8      Fairy     40
# 9   Fighting     53
# 10   Psychic     90
# 11      Rock     58
# 12     Ghost     46
# 13       Ice     38
# 14    Dragon     50
# 15      Dark     51
# 16     Steel     49
# 17    Flying    101

# %%
for i,r in types.iterrows():
    print(r.Type)
# Out:
# Grass
# Fire
# Water
# Bug
# Normal
# Poison
# Electric
# Ground
# Fairy
# Fighting
# Psychic
# Rock
# Ghost
# Ice
# Dragon
# Dark
# Steel
# Flying

# %%
for i,r in types.iterrows():
    df_type= pd.concat([df.loc[df['Type 1'] == r.Type] ,df.loc[df['Type 2'] == r.Type]])
    count=df_type.shape[0]
    types.loc[types['Type']==r.Type,'Count']=count

# %%
lengendTypes=pd.DataFrame(df['Type 1'].unique())
lengendTypes.rename(columns={0:'Type'}, inplace=True)
lengendTypes['Count']=0
legend = df.loc[df['Legendary'] == True]

# %%
for i,r in lengendTypes.iterrows():
    leg_type= pd.concat([legend.loc[legend['Type 1'] == r.Type] ,legend.loc[legend['Type 2'] == r.Type]])
    count=leg_type.shape[0]
    lengendTypes.loc[lengendTypes['Type']==r.Type,'Count']=count

# %%
lengendTypes
# Out:
#         Type  Count
# 0      Grass      3
# 1       Fire      8
# 2      Water      5
# 3        Bug      0
# 4     Normal      2
# 5     Poison      0
# 6   Electric      5
# 7     Ground      5
# 8      Fairy      3
# 9   Fighting      4
# 10   Psychic     19
# 11      Rock      4
# 12     Ghost      3
# 13       Ice      5
# 14    Dragon     16
# 15      Dark      3
# 16     Steel      5
# 17    Flying     15

# %%
lengendTypes.plot.pie(y='Count', labels=lengendTypes['Type'],autopct='%1.1f%%', figsize=(7, 7))
# Out:
# <Axes: ylabel='Count'>

# %%
types.plot.pie(y='Count', labels=lengendTypes['Type'],autopct='%1.1f%%', figsize=(7, 7))
# Out:
# <Axes: ylabel='Count'>

# %%
lengendTypes.sort_values('Count', ascending=False)
# Out:
#         Type  Count
# 10   Psychic     19
# 14    Dragon     16
# 17    Flying     15
# 1       Fire      8
# 13       Ice      5
# 2      Water      5
# 7     Ground      5
# 6   Electric      5
# 16     Steel      5
# 9   Fighting      4
# 11      Rock      4
# 0      Grass      3
# 12     Ghost      3
# 8      Fairy      3
# 15      Dark      3
# 4     Normal      2
# 3        Bug      0
# 5     Poison      0

# %%
df['Legendary'] = df['Legendary'].astype(int)
numeric_data= df.drop(['#','Name','Type 1', 'Type 2'], axis=1)

# %%
import matplotlib.pyplot as plt
numeric_data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(numeric_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,10))
for column in numeric_data.drop(['Legendary','Generation'],axis=1).columns:
    sns.boxplot(x='Legendary', y=column, data=df)
    plt.show()

# %%
legendbasedgen= df[['Generation','Legendary']]

# %%
legendbasedgen.groupby('Generation').sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Generation'>
